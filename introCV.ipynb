# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 載入影像

# %% [markdown]
# 影像也是資料的一種。
#
# `cv2.imread`就可以將影像資料轉換成我們熟悉的資料型別 - Numpy array

# %%
# 載入影像
image = cv2.imread("sim_data/images/dog.jpeg")

# 顯示影像
plt.imshow(image, cmap="gray"), plt.axis("off")
plt.show()

# %%
# 載入影像成灰階影像
image = cv2.imread("sim_data/images/dog.jpeg", cv2.IMREAD_GRAYSCALE)

# 顯示影像
plt.imshow(image, cmap="gray"), plt.axis("off")
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# 影像矩陣中的每一元素都分別對應到影像上的每一個像素（pixels）

# %%
# 影像矩陣
image
# Out:
# array([[ 51,  51,  51, ...,  80,  80,  80],
#        [ 51,  51,  51, ...,  80,  80,  80],
#        [ 51,  51,  51, ...,  80,  80,  80],
#        ...,
#        [156, 156, 156, ..., 142, 142, 142],
#        [156, 156, 156, ..., 142, 142, 142],
#        [155, 155, 155, ..., 142, 142, 142]], dtype=uint8)

# %% [markdown]
# 此影像的解析度是 3600 * 2270，所以該矩陣的尺寸/維度也會是這樣
#
# ![plane_info](archive/plane_info.png)

# %%
# 顯示該影像的矩陣維度
image.shape
# Out:
# (3024, 4032)

# %% [markdown]
# 那矩陣中每一個元素所代表的是什麼？
#
# 就灰階影像而言，每一個元素的值，就是對應像素的亮度（intensity）。
#
# 亮度值能從黑（0）到白（255）。

# %%
# slicing the very first element in array
image[0, 0]
# Out:
# 51

# %% [markdown]
# 假設讀入的影像是彩色的，在它所構成的矩陣中，每一個元素包含有三個值，分別對應藍、綠和紅（BGR）的值。

# %%
# 以彩色方式載入影像
image_bgr = cv2.imread("sim_data/images/dog.jpeg", cv2.IMREAD_COLOR)

# 顯示影像
plt.imshow(image_bgr), plt.axis("off")
# Out:
# (<matplotlib.image.AxesImage at 0x7fc663ba8e50>, (-0.5, 4031.5, 3023.5, -0.5))

# %%
# slicing the very first element in array
image_bgr[0, 0]
# Out:
# array([30, 59, 43], dtype=uint8)

# %% [markdown]
# 注意：`OpenCV`預設使用`BGR`，但許多影像軟體則使用紅、綠和藍（`RBG`）。
#
# 所以想在 matplotlib 中正確顯示 openCV 的彩色影像，需要先將顏色轉成 RGB。

# %%
# 轉成 RGB
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# 顯示影像
plt.imshow(image_rgb), plt.axis("off")
plt.show()

# %% [markdown]
# # 儲存影像

# %% [markdown]
# 需要注意的地方：`imwrite`會覆寫現有的檔案，而且不會有任何的提示/要求確認。

# %%
image = cv2.imread("sim_data/images/dog.jpeg", cv2.IMREAD_GRAYSCALE)

# saving the image
cv2.imwrite("sim_data/images/dog_new.jpeg", image)
# Out:
# True

# %% [markdown]
# # 影像大小的調整

# %%
image = cv2.imread("sim_data/images/dog.jpeg", cv2.IMREAD_GRAYSCALE)

# turn image into 50 * 50 pixels
image_50x50 = cv2.resize(image, (100, 100))

# check on image
plt.imshow(image_50x50, cmap="gray"), plt.axis("off")
plt.show()

# %% [markdown]
# 為什麼需要調整影像大小，且這還是一項常需進行的影像預處理工作。
